# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakhimovvv/Malumotlarni-uyg-unlashtirish-ulash-va-qayta-tiklash/blob/main/Ma%CA%BClumotlar_to%CA%BBplamlarini_ulash_%E2%80%93_concat()_%2C_pivot().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# fatal: destination path 'Practicum_Datasets' already exists and is not an empty directory.

# %%
bank = pd.read_csv("/content/Practicum_Datasets/bank.csv" , delimiter=";")
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
bank1 , bank2 = bank[:2225] , bank[2225:]
bank1
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      30   unemployed   married    primary      no     1787      no   no
# 1      33     services   married  secondary      no     4789     yes  yes
# 2      35   management    single   tertiary      no     1350     yes   no
# 3      30   management   married   tertiary      no     1476     yes  yes
# 4      59  blue-collar   married  secondary      no        0     yes   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 2220   33  blue-collar   married  secondary      no      139     yes  yes
# 2221   34   management   married   tertiary      no      573      no   no
# 2222   34       admin.   married  secondary      no      475     yes   no
# 2223   42  blue-collar  divorced  secondary      no       47     yes  yes
# 2224   46   management    single   tertiary      no     2154     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
pd.concat([bank1,bank2])
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
data1 = pd.read_csv("/content/Practicum_Datasets/data_pivot.csv")
data1.head()
# Out:
#                             date     item     value
# 0  1959-03-31 23:59:59.999999999  realgdp  2710.349
# 1  1959-03-31 23:59:59.999999999     infl     0.000
# 2  1959-03-31 23:59:59.999999999    unemp     5.800
# 3  1959-06-30 23:59:59.999999999  realgdp  2778.801
# 4  1959-06-30 23:59:59.999999999     infl     2.340

# %%
data_pivot = data1.pivot(index='date', columns='item', values='value')
data_pivot
# Out:
# item                           infl    realgdp  unemp
# date
# 1959-03-31 23:59:59.999999999  0.00   2710.349    5.8
# 1959-06-30 23:59:59.999999999  2.34   2778.801    5.1
# 1959-09-30 23:59:59.999999999  2.74   2775.488    5.3
# 1959-12-31 23:59:59.999999999  0.27   2785.204    5.6
# 1960-03-31 23:59:59.999999999  2.31   2847.699    5.2
# ...                             ...        ...    ...
# 2008-09-30 23:59:59.999999999 -3.16  13324.600    6.0
# 2008-12-31 23:59:59.999999999 -8.79  13141.920    6.9
# 2009-03-31 23:59:59.999999999  0.94  12925.410    8.1
# 2009-06-30 23:59:59.999999999  3.37  12901.504    9.2
# 2009-09-30 23:59:59.999999999  3.56  12990.341    9.6
#
# [203 rows x 3 columns]

# %%
data1['value2'] = np.random.randn(len(data1))
data1
# Out:
#                               date     item      value    value2
# 0    1959-03-31 23:59:59.999999999  realgdp   2710.349 -0.266243
# 1    1959-03-31 23:59:59.999999999     infl      0.000  0.176892
# 2    1959-03-31 23:59:59.999999999    unemp      5.800 -0.123210
# 3    1959-06-30 23:59:59.999999999  realgdp   2778.801  0.123455
# 4    1959-06-30 23:59:59.999999999     infl      2.340 -0.368729
# ..                             ...      ...        ...       ...
# 604  2009-06-30 23:59:59.999999999     infl      3.370  0.279207
# 605  2009-06-30 23:59:59.999999999    unemp      9.200 -0.120235
# 606  2009-09-30 23:59:59.999999999  realgdp  12990.341 -2.013188
# 607  2009-09-30 23:59:59.999999999     infl      3.560 -0.622368
# 608  2009-09-30 23:59:59.999999999    unemp      9.600  0.573602
#
# [609 rows x 4 columns]

# %%
pivoted_data = data1.pivot(index='date', columns='item')
pivoted_data
# Out:
#                               value                     value2            \
# item                           infl    realgdp unemp      infl   realgdp
# date
# 1959-03-31 23:59:59.999999999  0.00   2710.349   5.8  0.176892 -0.266243
# 1959-06-30 23:59:59.999999999  2.34   2778.801   5.1 -0.368729  0.123455
# 1959-09-30 23:59:59.999999999  2.74   2775.488   5.3 -0.085586  0.366587
# 1959-12-31 23:59:59.999999999  0.27   2785.204   5.6  0.156047  2.524835
# 1960-03-31 23:59:59.999999999  2.31   2847.699   5.2 -1.029650 -0.858273
# ...                             ...        ...   ...       ...       ...
# 2008-09-30 23:59:59.999999999 -3.16  13324.600   6.0  0.349703  0.162097
# 2008-12-31 23:59:59.999999999 -8.79  13141.920   6.9  1.067805 -0.411469
# 2009-03-31 23:59:59.999999999  0.94  12925.410   8.1  0.248597 -1.125446
# 2009-06-30 23:59:59.999999999  3.37  12901.504   9.2  0.279207  0.307853
# 2009-09-30 23:59:59.999999999  3.56  12990.341   9.6 -0.622368 -2.013188
#
#
# ...
