# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakhimovvv/Malumotlarni-uyg-unlashtirish-ulash-va-qayta-tiklash/blob/main/Untitled32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# fatal: destination path 'Practicum_Datasets' already exists and is not an empty directory.

# %%
df = pd.read_csv("/content/Practicum_Datasets/world_cities_air_water_quality.csv")
df
# Out:
#                   City                 "Region"                    "Country"  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#        "AirQuality"   "WaterPollution"
# ...

# %%
df.shape
# Out:
# (3963, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3963 entries, 0 to 3962
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               3963 non-null   object
#  1    "Region"          3963 non-null   object
#  2    "Country"         3963 non-null   object
#  3    "AirQuality"      3963 non-null   float64
#  4    "WaterPollution"  3963 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 154.9+ KB

# %%
columns = ["City" , "Region" , "Country" , "Airqulity" , "Waterpollution"]
df.columns = columns
df
# Out:
#                   City                   Region                      Country  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#        Airqulity  Waterpollution
# ...

# %%
df["Region"] = df['Region'].map(lambda x: x.replace('"',""))
df
# Out:
#                   City                 Region                      Country  \
# 0        New York City               New York   "United States of America"
# 1     Washington, D.C.   District of Columbia   "United States of America"
# 2        San Francisco             California   "United States of America"
# 3               Berlin                                           "Germany"
# 4          Los Angeles             California   "United States of America"
# ...                ...                    ...                          ...
# 3958             Yanbu        Medina Province               "Saudi Arabia"
# 3959           Cordoba              Andalusia                      "Spain"
# 3960               Vic              Catalonia                      "Spain"
# 3961           Segovia       Castile and Leon                      "Spain"
# 3962       Zamora city       Castile and Leon                      "Spain"
#
#        Airqulity  Waterpollution
# 0      46.816038       49.504950
# ...

# %%
df['Country'] = df['Country'].map(lambda x: x.replace('"',""))
df
# Out:
#                   City                 Region                    Country  \
# 0        New York City               New York   United States of America
# 1     Washington, D.C.   District of Columbia   United States of America
# 2        San Francisco             California   United States of America
# 3               Berlin                                           Germany
# 4          Los Angeles             California   United States of America
# ...                ...                    ...                        ...
# 3958             Yanbu        Medina Province               Saudi Arabia
# 3959           Cordoba              Andalusia                      Spain
# 3960               Vic              Catalonia                      Spain
# 3961           Segovia       Castile and Leon                      Spain
# 3962       Zamora city       Castile and Leon                      Spain
#
#        Airqulity  Waterpollution
# 0      46.816038       49.504950
# ...

# %%
df[df["Country"] == "Spain"]
# Out:
# Empty DataFrame
# Columns: [City, Region, Country, Airqulity, Waterpollution]
# Index: []

# %%
df["Country"][3]
# Out:
# ' Germany'

# %%
df['Country'] = df['Country'].map(lambda x: x.strip())  # strip bo'sh joyni yo'q qiladi
df
# Out:
#                   City                 Region                   Country  \
# 0        New York City               New York  United States of America
# 1     Washington, D.C.   District of Columbia  United States of America
# 2        San Francisco             California  United States of America
# 3               Berlin                                          Germany
# 4          Los Angeles             California  United States of America
# ...                ...                    ...                       ...
# 3958             Yanbu        Medina Province              Saudi Arabia
# 3959           Cordoba              Andalusia                     Spain
# 3960               Vic              Catalonia                     Spain
# 3961           Segovia       Castile and Leon                     Spain
# 3962       Zamora city       Castile and Leon                     Spain
#
#        Airqulity  Waterpollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %%
df[df['Country'] == 'Spain']
# Out:
#              City                Region Country   Airqulity  Waterpollution
# 116     Barcelona             Catalonia   Spain   35.497238       51.315789
# 240        Madrid   Community of Madrid   Spain   36.234177       18.954248
# 443        Toledo     Castile-La Mancha   Spain   75.000000       50.000000
# 489        Girona             Catalonia   Spain  100.000000        0.000000
# 505    Valladolid      Castile and Leon   Spain   70.000000       41.666667
# ...           ...                   ...     ...         ...             ...
# 3956     Palencia      Castile and Leon   Spain   79.166667       37.500000
# 3959      Cordoba             Andalusia   Spain   85.714286        8.333333
# 3960          Vic             Catalonia   Spain  100.000000        0.000000
# 3961      Segovia      Castile and Leon   Spain  100.000000        0.000000
# 3962  Zamora city      Castile and Leon   Spain  100.000000       50.000000
#
# [78 rows x 5 columns]

# %%
df.to_csv("world_cities_air_water_quality.csv" , index = False)

# %%
df
# Out:
#                   City                 Region                   Country  \
# 0        New York City               New York  United States of America
# 1     Washington, D.C.   District of Columbia  United States of America
# 2        San Francisco             California  United States of America
# 3               Berlin                                          Germany
# 4          Los Angeles             California  United States of America
# ...                ...                    ...                       ...
# 3958             Yanbu        Medina Province              Saudi Arabia
# 3959           Cordoba              Andalusia                     Spain
# 3960               Vic              Catalonia                     Spain
# 3961           Segovia       Castile and Leon                     Spain
# 3962       Zamora city       Castile and Leon                     Spain
#
#        Airqulity  Waterpollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %%
df1 = pd.pivot_table(df , index = ["Country" , "City"] )
df1.index

# %%
df1.loc['Uzbekistan']
# Out:
#           Airqulity  Region  Waterpollution
# City
# Tashkent          1       1               1
